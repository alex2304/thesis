# %%
import nltk
import numpy as np
import pandas as pd

from nltk.corpus import gutenberg, brown, reuters, stopwords

from collections import Counter, defaultdict
from pprint import pprint

from utils.nltk_utils import *
from utils.ngrams import *
from utils.grammar import parse_phrases

stop_words = stopwords.words('english')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-5b5eda82bad8> in <module>()
# ----> 1 import nltk
#       2 import numpy as np
#       3 import pandas as pd
#       4
#       5 from nltk.corpus import gutenberg, brown, reuters, stopwords
#
# ImportError: No module named 'nltk'

# %%
for fileid in gutenberg.fileids():
    num_chars = len(gutenberg.raw(fileid))
    num_words = len(gutenberg.words(fileid))
    num_sents = len(gutenberg.sents(fileid))
    num_vocab = len(set(w.lower() for w in gutenberg.words(fileid)))
    print(round(num_chars/num_words), round(num_words/num_sents), round(num_words/num_vocab), fileid)
# Out:
# 5 25 26 austen-emma.txt
# 5 26 17 austen-persuasion.txt
# 5 28 22 austen-sense.txt
# 4 34 79 bible-kjv.txt
# 5 19 5 blake-poems.txt
# 4 19 14 bryant-stories.txt
# 4 18 12 burgess-busterbrown.txt
# 4 20 13 carroll-alice.txt
# 5 20 12 chesterton-ball.txt
# 5 23 11 chesterton-brown.txt
# 5 18 11 chesterton-thursday.txt
# 4 21 25 edgeworth-parents.txt
# 5 26 15 melville-moby_dick.txt
# 5 52 11 milton-paradise.txt
# 4 12 9 shakespeare-caesar.txt
# 4 12 8 shakespeare-hamlet.txt
# 4 12 7 shakespeare-macbeth.txt
# 5 36 12 whitman-leaves.txt

# %%
sents = gutenberg.sents() + brown.sents() + reuters.sents()

words = [w.lower() for s in sents for w in s]
vocab = list(set(words))

print('Sents:', len(sents))
print('Words:', len(words))
print('Vocab:', len(vocab))
# Out:
# Sents: 210608
# Words: 5503894
# Vocab: 87046

# %% [markdown]
# # Сheck coverage of dictionary from Lingualeo

# %%
df = pd.read_csv('data/lingualeo_words.csv', header=None)[[0]]

d_words = df.as_matrix().reshape(df.shape[0])

d_words = set([p.lower().replace(',', '').strip() for w in d_words for p in w.split(' ')])

print('Dictionary words:', len(d_words))
# Out:
# Dictionary words: 874

# %%
print('Common percent:', len(d_words.intersection(vocab)) / len(d_words))

absent_words = d_words.difference(vocab)

print('Absent words: %s out of %s' % (len(absent_words), len(d_words)))
# pprint(absent_words)
# Out:
# Common percent: 0.9233409610983981
# Absent words: 67 out of 874

# %% [markdown]
# # Experiments with lemmas and stems

# %% [markdown]
# ## Lemmatizing

# %%
ttokens = nltk.pos_tag(vocab)

lemmatizer = Lemmatizer()

# {token: lemma}
lemmas = {token: lemmatizer.lemmatize(token, tag) 
          for token, tag in ttokens}

print('Lemmas:', len(set(lemmas.values())))
# Out:
# Lemmas: 72467

# %%
# {lemma: Set[sentence_ind]}
lemmas_sents = defaultdict(set)

for i, s in enumerate(sents):
    for w in s:
        l = lemmas[w.lower()]
        
        lemmas_sents[l].add(i)
        
print('Lemmas have sentences:', len(lemmas_sents))
# Out:
# Lemmas have sentences: 72467

# %%
tw = 'grievance'

sw = list(lemmas_sents[tw])

print(len(sw))

' '.join(sents[sw[2]])
# Out:
# 17
# 'They said Nigeria , which holds the OPEC conference presidency , and Qatar probably have the biggest grievances about price differentials making some of their crudes uncompetitive .'

# %% [markdown]
# ## Check vocab coverage with lemmas

# %%
d_words_lemmas = set([lemmatizer.lemmatize(token, tag) 
                      for token, tag in nltk.pos_tag(d_words)])

# %%
_lemmas = lemmas.values()

print('Common percent:', len(d_words_lemmas.intersection(_lemmas)) / len(d_words_lemmas))

absent_words = d_words_lemmas.difference(_lemmas)

print('Absent words: %s out of %s' % (len(absent_words), len(d_words_lemmas)))
# pprint(absent_words)
# Out:
# Common percent: 0.9237089201877934
# Absent words: 65 out of 852

# %% [markdown]
# ## Stemming

# %%
stemmer = Stemmer()

# {token: stem}
stems = {token: stemmer.stem(token) 
         for token, _ in ttokens}

print('Stems:', len(set(stems.values())))
# Out:
# Stems: 58856

# %%
# {stem: Set[sentence_ind]}
stems_sents = defaultdict(set)

for i, s in enumerate(sents):
    for w in s:
        st = stems[w.lower()]
        
        stems_sents[st].add(i)
        
print('Stems have sentences:', len(stems_sents))
# Out:
# Stems have sentences: 58856

# %% [markdown]
# ## Check vocab coverage with stems

# %%
d_words_stems = set([stemmer.stem(w) for w in d_words])

# %%
_stems = stems.values()

print('Common percent:', len(d_words_stems.intersection(_stems)) / len(d_words_stems))

absent_words = d_words_stems.difference(_stems)

print('Absent words: %s out of %s' % (len(absent_words), len(d_words_stems)))
# pprint(absent_words)
# Out:
# Common percent: 0.9577804583835947
# Absent words: 35 out of 829

# %% [markdown]
# # Phrases extraction

# %%
parser = NGramsParser()
words_ttokens = nltk.pos_tag(words)

tokens_indexes = parser.parse_tokens(words)

# %%
# {word: Set[phrase]}
words_phrases = defaultdict(set)

for i in range(1, 5 + 1):
    tt_ngrams = list(n_grams(words_ttokens, i, tokens_indexes, pad_left=False))

    types, phrases = parse_phrases(tt_ngrams, i)

    for t, p in zip(types, phrases):
        words_phrases[t].add(p)
# Out:
# parsing phrases from 1-grams: 100%|██████████| 4768859/4768859 [00:30<00:00, 154577.58it/s]
# parsing phrases from 2-grams: 100%|██████████| 4057518/4057518 [00:28<00:00, 141489.05it/s]
# parsing phrases from 3-grams: 100%|██████████| 3456422/3456422 [00:21<00:00, 159277.54it/s]
# parsing phrases from 4-grams: 100%|██████████| 2921233/2921233 [00:26<00:00, 110953.44it/s]
# parsing phrases from 5-grams: 100%|██████████| 2451678/2451678 [00:27<00:00, 90633.10it/s]
# parsing phrases from 6-grams: 100%|██████████| 2051602/2051602 [00:24<00:00, 85017.92it/s]

# %% [markdown]
# ## Caching data

# %%
import pickle

with open('data/cache/words_phrases', mode='wb') as fp:
    pickle.dump(words_phrases, fp)

# %%
with open('data/cache/lemmas', mode='wb') as fp:
    pickle.dump(lemmas, fp)
    
with open('data/cache/lemmas_sents', mode='wb') as fp:
    pickle.dump(lemmas_sents, fp)

# %%
with open('data/cache/stems', mode='wb') as fp:
    pickle.dump(stems, fp)
    
with open('data/cache/stems_sents', mode='wb') as fp:
    pickle.dump(stems_sents, fp)

# %% [markdown]
# ## Experiments with phrases

# %%
lemmas_ttokens = defaultdict(set)

for token, tag in words_ttokens:
    l = lemmas[token]
    
    lemmas_ttokens[l].add((token, tag))

# %%
def only_stopwords_phrase(phrase, phr_intersection):
    return any([tt for tt in phrase if tt not in phr_intersection and tt[0] not in stop_words])
    
def get_phrases_containing(lemma: str, size=None):
    # if size:
    #     indexed_phrases =
    #
    # if tag.startswith('N'):
    #     phrase_type = 'NP'
    # elif tag.startswith('V'):
    #     phrase_type = 'VP'
    # elif tag in ['IN', 'TO']:
    #     phrase_type = 'PP'
    # elif tag in ['JJ', 'RB']:
    #     phrase_type = 'ADJP'
    # else:
    #     raise NotImplementedError(tag)

    # TODO: options which phrases to return
    
    ttokens = set(tt for tt in lemmas_ttokens.get(lemma, []))

    stopwords_phrases, not_sw_phrases = defaultdict(list), defaultdict(list)
    
    if ttokens:
        for phr_type, phrases in words_phrases.items():
            for phrase in list(phrases):
                common_ttokens = ttokens.intersection(phrase)
                
                if common_ttokens:
                    if only_stopwords_phrase(phrase, common_ttokens):
                        stopwords_phrases[phr_type].append(phrase)
                    else:
                        not_sw_phrases[phr_type].append(phrase)
                        
    return stopwords_phrases, not_sw_phrases

# %%
def explore_vocab():
    phr_length = dict()
    
    for phr_type, phrases in words_phrases.items():
        phr_length[phr_type] = defaultdict(int)
        
        for phr in phrases:
            phr_length[phr_type][len(phr)] += 1
        
    return phr_length

explore_vocab()
# Out:
# {'ADJP': defaultdict(int, {1: 25575, 2: 90057, 3: 18988, 4: 1814, 5: 87}),
#  'ADVP': defaultdict(int, {1: 9387, 2: 106481, 3: 15773, 4: 117}),
#  'NP': defaultdict(int,
#              {1: 65971, 2: 481015, 3: 430109, 4: 130492, 5: 12662, 6: 845}),
#  'PP': defaultdict(int, {1: 1580, 2: 868, 3: 4153}),
#  'VP': defaultdict(int, {1: 35510, 2: 19966, 3: 2581})}

# %%
not_sw, sw = get_phrases_containing('dormitory')

not_sw
# Out:
# defaultdict(list,
#             {'NP': [(('build', 'VB'), ('dormitories', 'NNS')),
#               (('campus', 'NN'), ('dormitories', 'NNS')),
#               (('the', 'DT'), ('dormitory', 'NN'), ('gapt', 'NN')),
#               (('the', 'DT'),
#                ('dormitory', 'NN'),
#                ('and', 'CC'),
#                ('dining', 'VBG')),
#               (('the', 'DT'), ('campus', 'NN'), ('dormitories', 'NNS')),
#               (('dormitory', 'NN'), ('gapt', 'NN')),
#               (('dormitory', 'NN'), ('and', 'CC'), ('dining', 'VBG'))]})

# %%
def extract_phrases_length(phrases_dict):
    voc = defaultdict(list)
    
    for p_type, phrases in phrases_dict.items():
        for phr in phrases:
            voc[len(phr)].append(phr)
            
    return voc

extract_phrases_length(not_sw)
# Out:
# defaultdict(list,
#             {2: [(('plant', 'NN'), ('facilities', 'NNS')),
#               (('merger', 'NN'), ('facility', 'NN')),
#               (('last', 'JJ'), ('facility', 'NN')),
#               (('trade', 'NN'), ('facility', 'NN')),
#               (('recreational', 'VB'), ('facilities', 'NNS')),
#               (('coop', 'NN'), ('facility', 'NN')),
#               (('leased', 'VBN'), ('facilities', 'NNS')),
#               (('food-preservation', 'NN'), ('facilities', 'NNS')),
#               (('private-school', 'NN'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('dynalectron', 'NNP')),
#               (('better', 'JJR'), ('facilities', 'NNS')),
#               (('waterfront', 'NN'), ('facility', 'NN')),
#               (('combustion', 'NN'), ('facility', 'NN')),
#               (('100', 'CD'), ('facility', 'NN')),
#               (('28', 'CD'), ('facilities', 'NNS')),
#               (('credit', 'NN'), ('facility', 'NN')),
#               (('housing', 'NN'), ('facilities', 'NNS')),
#               (('church', 'NN'), ('facilities', 'NNS')),
#               (('offered', 'VBN'), ('facilities', 'NNS')),
#               (('shore', 'NN'), ('facilities', 'NNS')),
#               (('euromarket', 'NN'), ('facility', 'NN')),
#               (('regional', 'JJ'), ('facility', 'NN')),
#               (('processing', 'VBG'), ('facility', 'NN')),
#               (('factory', 'NN'), ('facilities', 'NNS')),
#               (('shooting', 'VBG'), ('facilities', 'NNS')),
#               (('day', 'NN'), ('facility', 'NN')),
#               (('ground', 'NN'), ('facilities', 'NNS')),
#               (('ssmc', 'NN'), ('facility', 'NN')),
#               (('underwriting', 'VBG'), ('facilities', 'NNS')),
#               (('upgraded', 'JJ'), ('facility', 'NN')),
#               (('donaldson', 'NN'), ('facility', 'NN')),
#               (('panoche', 'NN'), ('facility', 'NN')),
#               (('fiber', 'NN'), ('facilities', 'NNS')),
#               (('distribution', 'NN'), ('facilities', 'NNS')),
#               (('extensive', 'JJ'), ('facilities', 'NNS')),
#               (('eating', 'VBG'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('rate', 'NN')),
#               (('facilities', 'NNS'), ('early', 'RB')),
#               (('toilet', 'NN'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('due', 'JJ')),
#               (('slaughtering', 'NN'), ('facility', 'NN')),
#               (('club', 'NN'), ('facility', 'NN')),
#               (('maintenance', 'NN'), ('facility', 'NN')),
#               (('rehabilitation', 'NN'), ('facilities', 'NNS')),
#               (('generation', 'NN'), ('facility', 'NN')),
#               (('feeding', 'NN'), ('facilities', 'NNS')),
#               (('barbecue', 'VBN'), ('facilities', 'NNS')),
#               (('new', 'JJ'), ('facilities', 'NNS')),
#               (('physical', 'JJ'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('."', 'NN')),
#               (('train', 'NN'), ('facilities', 'NNS')),
#               (('dealer', 'NN'), ('facilities', 'NNS')),
#               (('mill', 'NN'), ('facilities', 'NNS')),
#               (('lettershop', 'NN'), ('facilities', 'NNS')),
#               (('buy', 'VB'), ('facility', 'NN')),
#               (('pipeline', 'NN'), ('facility', 'NN')),
#               (('facility', 'NN'), ('directly', 'RB')),
#               (('recreation', 'NN'), ('facilities', 'NNS')),
#               (('various', 'JJ'), ('facilities', 'NNS')),
#               (('city', 'NN'), ('facility', 'NN')),
#               (('extra', 'JJ'), ('facilities', 'NNS')),
#               (("ica's", 'NN'), ('facilities', 'NNS')),
#               (('pct', 'JJ'), ('facility', 'NN')),
#               (('offer', 'NN'), ('facility', 'NN')),
#               (('loan', 'NN'), ('facility', 'NN')),
#               (('swap', 'NN'), ('facilities', 'NNS')),
#               (('inadequate', 'NN'), ('facilities', 'NNS')),
#               (('public', 'JJ'), ('facilities', 'NNS')),
#               (('educational', 'JJ'), ('facilities', 'NNS')),
#               (('processing', 'NN'), ('facilities', 'NNS')),
#               (('hedging', 'VBG'), ('facilities', 'NNS')),
#               (('small', 'JJ'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('inventories', 'NNS')),
#               (('facilities', 'NNS'), (',"', 'NNP')),
#               (('aviation', 'NN'), ('facility', 'NN')),
#               (('storage', 'NN'), ('facility', 'NN')),
#               (('maytag', 'NN'), ('facilities', 'NNS')),
#               (('spencer', 'NN'), ('facilities', 'NNS')),
#               (('good', 'JJ'), ('facilities', 'NNS')),
#               (('financing', 'VBG'), ('facility', 'NN')),
#               (('weather', 'NN'), ('facility', 'NN')),
#               (('underutilized', 'VBN'), ('facilities', 'NNS')),
#               (('facilities', 'NNS'), ('inventory', 'NN')),
#               (('bed', 'NN'), ('facility', 'NN')),
#               (('champion', 'NN'), ('facilities', 'NNS')),
#               (('attendant', 'NN'), ('facilities', 'NNS')),
#               (('credit', 'NN'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('loans', 'NNS')),
#               (('emergency', 'NN'), ('facilities', 'NNS')),
#               (('financing', 'NN'), ('facility', 'NN')),
#               (('lexington', 'NN'), ('facility', 'NN')),
#               (('oil', 'NN'), ('facility', 'NN')),
#               (('oil', 'NN'), ('facilities', 'NNS')),
#               (('care', 'NN'), ('facilities', 'NNS')),
#               (('carolina', 'NN'), ('facilities', 'NNS')),
#               (('loan', 'NN'), ('facilities', 'NNS')),
#               (('borrowing', 'NN'), ('facilities', 'NNS')),
#               (('ip', 'NN'), ('facilities', 'NNS')),
#               (('weather', 'PRP$'), ('facility', 'NN')),
#               (('borrowing', 'VBG'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('adjoining', 'VBG')),
#               (('margin', 'NN'), ('facility', 'NN')),
#               (('whole', 'JJ'), ('facility', 'NN')),
#               (('chemical', 'NN'), ('facilities', 'NNS')),
#               (('hydroelectric', 'NN'), ('facilities', 'NNS')),
#               (('storage', 'NN'), ('facilities', 'NNS')),
#               (('nursing', 'VBG'), ('facilities', 'NNS')),
#               (('federal', 'JJ'), ('facilities', 'NNS')),
#               (("weren't", 'JJ'), ('facilities', 'NNS')),
#               (('purpose', 'NN'), ('facility', 'NN')),
#               (('adjoining', 'VBG'), ('facility', 'NN')),
#               (('contingency', 'NN'), ('facility', 'NN')),
#               (('feeding', 'VBG'), ('facilities', 'NNS')),
#               (('productive', 'JJ'), ('facilities', 'NNS')),
#               (('coal', 'NN'), ('facility', 'NN')),
#               (('necessary', 'JJ'), ('facilities', 'NNS')),
#               (('transmission', 'NN'), ('facilities', 'NNS')),
#               (('needed', 'JJ'), ('facilities', 'NNS')),
#               (('earlier', 'JJR'), ('facility', 'NN')),
#               (('facility', 'NN'), ('ever', 'RB')),
#               (('improved', 'VBN'), ('facilities', 'NNS')),
#               (('refining', 'NN'), ('facilities', 'NNS')),
#               (('complete', 'JJ'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('expiring', 'VBG')),
#               (('medical', 'JJ'), ('facilities', 'NNS')),
#               (('operated', 'VBN'), ('facility', 'NN')),
#               (('two', 'CD'), ('facilities', 'NNS')),
#               (('facilities', 'NNS'), ('inventory', 'JJ')),
#               (('facility', 'NN'), ('improvements', 'NNS')),
#               (('office', 'NN'), ('facilities', 'NNS')),
#               (('bank', 'NN'), ('facilities', 'NNS')),
#               (('facilities', 'NNS'), ('available', 'JJ')),
#               (('headquarter', 'NN'), ('facilities', 'NNS')),
#               (("sba's", 'NN'), ('facilities', 'NNS')),
#               (('repair', 'NN'), ('facilities', 'NNS')),
#               (('bottling', 'NN'), ('facilities', 'NNS')),
#               (('idle', 'JJ'), ('facilities', 'NNS')),
#               (('acid', 'JJ'), ('facility', 'NN')),
#               (('facility', 'NN'), ('expansion', 'NN')),
#               (('treatment', 'NN'), ('facilities', 'NNS')),
#               (('duplicate', 'NN'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('transfer', 'NN')),
#               (('paribas', 'NN'), ('facility', 'NN')),
#               (('research', 'NN'), ('facilities', 'NNS')),
#               (('production', 'NN'), ('facilities', 'NNS')),
#               (('certain', 'JJ'), ('facilities', 'NNS')),
#               (('facilities', 'NNS'), ('formerly', 'RB')),
#               (('testing', 'VBG'), ('facilities', 'NNS')),
#               (('hospital', 'NN'), ('facilities', 'NNS')),
#               (('proposed', 'VBN'), ('facilities', 'NNS')),
#               (('export', 'NN'), ('facilities', 'NNS')),
#               (('garage', 'NN'), ('facilities', 'NNS')),
#               (('options', 'NNS'), ('facility', 'NN')),
#               (('facility', 'NN'), ('banque', 'NN')),
#               (('port', 'NN'), ('facilities', 'NNS')),
#               (('local', 'JJ'), ('facilities', 'NNS')),
#               (('lending', 'NN'), ('facilities', 'NNS')),
#               (('facilities', 'NNS'), ('40', 'CD')),
#               (('adjustment', 'NN'), ('facility', 'NN')),
#               (('manufacturing', 'NN'), ('facility', 'NN')),
#               (('treating', 'NN'), ('facilities', 'NNS')),
#               (('manufacturing', 'NN'), ('facilities', 'NNS')),
#               (('expanding', 'VBG'), ('facilities', 'NNS')),
#               (('fractionation', 'NN'), ('facility', 'NN')),
#               (('financing', 'NN'), ('facilities', 'NNS')),
#               (('public', 'JJ'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('overseas', 'RB')),
#               (('borrowing', 'NN'), ('facility', 'NN')),
#               (('theatrical', 'JJ'), ('facilities', 'NNS')),
#               (('training', 'NN'), ('facilities', 'NNS')),
#               (('proper', 'NN'), ('facilities', 'NNS')),
#               (('radiation', 'NN'), ('facilities', 'NNS')),
#               (('provide', 'VB'), ('facilities', 'NNS')),
#               (('debt', 'NN'), ('facility', 'NN')),
#               (('new', 'JJ'), ('facility', 'NN')),
#               (('multiple', 'JJ'), ('facilities', 'NNS')),
#               (('different', 'JJ'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('steadily', 'RB')),
#               (('grain-storage', 'NN'), ('facilities', 'NNS')),
#               (('production', 'NN'), ('facility', 'NN')),
#               (('funding', 'VBG'), ('facility', 'NN')),
#               (('year', 'NN'), ('facility', 'NN')),
#               (('basic', 'JJ'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('replaces', 'NNS')),
#               (('excess', 'JJ'), ('facilities', 'NNS')),
#               (('special', 'JJ'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('devoted', 'VBN')),
#               (('facility', 'NN'), ('owned', 'VBN'))],
#              3: [(('permanent', 'JJ'),
#                ('production', 'NN'),
#                ('facilities', 'NNS')),
#               (('facility', 'NN'), ('banque', 'NN'), ('paribas', 'NN')),
#               (('temporary', 'JJ'), ('lending', 'NN'), ('facilities', 'NNS')),
#               (('use', 'VB'), ('borrowing', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('productive', 'JJ'), ('facilities', 'NNS')),
#               (('medical', 'JJ'), ('care', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('ssmc', 'NN'), ('facility', 'NN')),
#               (('syndicated', 'VBN'), ('credit', 'NN'), ('facility', 'NN')),
#               (('largely', 'RB'), ('upgraded', 'JJ'), ('facility', 'NN')),
#               (('specialized', 'JJ'),
#                ('rehabilitation', 'NN'),
#                ('facilities', 'NNS')),
#               (('acquiring', 'VBG'),
#                ('grain-storage', 'NN'),
#                ('facilities', 'NNS')),
#               (('revolving', 'NN'), ('credit', 'NN'), ('facility', 'NN')),
#               (('a', 'DT'), ('borrowing', 'NN'), ('facility', 'NN')),
#               (('s', 'NN'), ('manufacturing', 'NN'), ('facilities', 'NNS')),
#               (('no', 'DT'), ('small', 'JJ'), ('facility', 'NN')),
#               (('this', 'DT'), ('euromarket', 'NN'), ('facility', 'NN')),
#               (('facility', 'NN'), ('expansion', 'NN'), ('program', 'NN')),
#               (('share', 'NN'), ('medical', 'JJ'), ('facilities', 'NNS')),
#               (('south', 'JJ'), ('carolina', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('basic', 'JJ'), ('facilities', 'NNS')),
#               (('local', 'JJ'), ('medical', 'JJ'), ('facilities', 'NNS')),
#               (('acrylic', 'JJ'), ('acid', 'JJ'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('incitements', 'NNS')),
#               (('dlr', 'NN'), ('margin', 'NN'), ('facility', 'NN')),
#               (('iranian', 'JJ'), ('export', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('28', 'CD'), ('facilities', 'NNS')),
#               (('single', 'JJ'), ('manufacturing', 'NN'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('refreshments', 'NNS')),
#               (('a', 'DT'), ('facility', 'NN'), ('expiring', 'VBG')),
#               (('rock', 'NN'), ('coop', 'NN'), ('facility', 'NN')),
#               (('international', 'JJ'),
#                ('refining', 'NN'),
#                ('facilities', 'NNS')),
#               (('equipment', 'NN'), ('and', 'CC'), ('facilities', 'NNS')),
#               (('revelving', 'VBG'), ('credit', 'NN'), ('facility', 'NN')),
#               (('of', 'IN'), ('idle', 'JJ'), ('facilities', 'NNS')),
#               (('emergency', 'NN'), ('financing', 'NN'), ('facility', 'NN')),
#               (('compensatory', 'NN'),
#                ('financing', 'VBG'),
#                ('facility', 'NN')),
#               (('emcf', 'NN'), ('swap', 'NN'), ('facilities', 'NNS')),
#               (('health', 'NN'), ('club', 'NN'), ('facility', 'NN')),
#               (('the', 'DT'), ('educational', 'JJ'), ('facilities', 'NNS')),
#               (('its', 'PRP$'), ('production', 'NN'), ('facilities', 'NNS')),
#               (('acquiring', 'VBG'),
#                ('emergency', 'NN'),
#                ('facilities', 'NNS')),
#               (('central', 'JJ'), ('production', 'NN'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('activities', 'NNS')),
#               (('100', 'CD'), ('facility', 'NN'), ('expansion', 'NN')),
#               (('the', 'DT'), ('theatrical', 'JJ'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('merger', 'NN'), ('facility', 'NN')),
#               (('microchip', 'NN'),
#                ('production', 'NN'),
#                ('facilities', 'NNS')),
#               (('its', 'PRP$'), ('lexington', 'NN'), ('facility', 'NN')),
#               (('oil', 'NN'), ('facility', 'NN'), ('banque', 'NN')),
#               (('the', 'DT'), ('trade', 'NN'), ('facility', 'NN')),
#               (('an', 'DT'), ('earlier', 'JJR'), ('facility', 'NN')),
#               (('other', 'JJ'),
#                ('private-school', 'NN'),
#                ('facilities', 'NNS')),
#               (('her', 'PRP$'), ('special', 'JJ'), ('facilities', 'NNS')),
#               (('panoche', 'NN'), ('treatment', 'NN'), ('facilities', 'NNS')),
#               (('largest', 'JJS'), ('credit', 'NN'), ('facility', 'NN')),
#               (('dlr', 'NN'), ('credit', 'NN'), ('facility', 'NN')),
#               (('structural', 'JJ'), ('adjustment', 'NN'), ('facility', 'NN')),
#               (('its', 'PRP$'), ('facilities', 'NNS'), ('steadily', 'RB')),
#               (('consolidate', 'NN'),
#                ('various', 'JJ'),
#                ('facilities', 'NNS')),
#               (('fluidized', 'JJ'), ('bed', 'NN'), ('facility', 'NN')),
#               (('other', 'JJ'), ('maytag', 'NN'), ('facilities', 'NNS')),
#               (('emergency', 'NN'), ('funding', 'VBG'), ('facility', 'NN')),
#               (('on', 'IN'), ('new', 'JJ'), ('facilities', 'NNS')),
#               (('a', 'DT'), ('public', 'JJ'), ('facility', 'NN')),
#               (('cold', 'JJ'), ('storage', 'NN'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('test', 'NN')),
#               (('a', 'DT'), ('donaldson', 'NN'), ('facility', 'NN')),
#               (('second', 'JJ'), ('contingency', 'NN'), ('facility', 'NN')),
#               (('new', 'JJ'), ('plant', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('panoche', 'NN'), ('facility', 'NN')),
#               (('support', 'NN'), ('contingency', 'NN'), ('facility', 'NN')),
#               (('poor', 'JJ'), ('processing', 'NN'), ('facilities', 'NNS')),
#               (('adequate', 'JJ'), ('hospital', 'NN'), ('facilities', 'NNS')),
#               (('compensatory', 'NN'),
#                ('financing', 'NN'),
#                ('facility', 'NN')),
#               (('adequate', 'JJ'), ('repair', 'NN'), ('facilities', 'NNS')),
#               (('existing', 'VBG'),
#                ('production', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'), ('facility', 'NN'), ('directly', 'RB')),
#               (('aviation', 'NN'), ('facility', 'NN'), ('dynalectron', 'NNP')),
#               (('their', 'PRP$'), ('borrowing', 'NN'), ('facilities', 'NNS')),
#               (('your', 'PRP$'), ('feeding', 'NN'), ('facilities', 'NNS')),
#               (('of', 'IN'), ('multiple', 'JJ'), ('facilities', 'NNS')),
#               (('these', 'DT'), ('improved', 'VBN'), ('facilities', 'NNS')),
#               (('year', 'NN'), ('100', 'CD'), ('facility', 'NN')),
#               (('bed', 'NN'), ('combustion', 'NN'), ('facility', 'NN')),
#               (('radio', 'NN'), ('transmission', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('paribas', 'NN'), ('facility', 'NN')),
#               (('the', 'DT'), ('proper', 'NN'), ('facilities', 'NNS')),
#               (('other', 'JJ'), ('ip', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('church', 'NN'), ('facilities', 'NNS')),
#               (('its', 'PRP$'),
#                ('manufacturing', 'NN'),
#                ('facilities', 'NNS')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('disposal', 'NN')),
#               (('term', 'NN'), ('financing', 'NN'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('the', 'DT'), ('bank', 'NN')),
#               (('three', 'CD'), ('nursing', 'VBG'), ('facilities', 'NNS')),
#               (('a', 'DT'), ('credit', 'NN'), ('facility', 'NN')),
#               (('bird', 'NN'), ('dealer', 'NN'), ('facilities', 'NNS')),
#               (('revolving', 'VBG'), ('credit', 'NN'), ('facility', 'NN')),
#               (('its', 'PRP$'), ('inadequate', 'NN'), ('facilities', 'NNS')),
#               (('paper', 'NN'), ('mill', 'NN'), ('facilities', 'NNS')),
#               (('inadequate', 'JJ'),
#                ('distribution', 'NN'),
#                ('facilities', 'NNS')),
#               (('program', 'NN'), ('and', 'CC'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('whole', 'JJ'), ('facility', 'NN')),
#               (('restricted', 'JJ'), ('toilet', 'NN'), ('facilities', 'NNS')),
#               (('agriculture', 'NN'), ('weather', 'PRP$'), ('facility', 'NN')),
#               (('facility', 'NN'), ('&', 'CC'), ('lt', 'NN')),
#               (('the', 'DT'), ('physical', 'JJ'), ('facilities', 'NNS')),
#               (('a', 'DT'), ('waterfront', 'NN'), ('facility', 'NN')),
#               (('the', 'DT'), ('oil', 'NN'), ('facility', 'NN')),
#               (('sixth', 'JJ'), ('production', 'NN'), ('facility', 'NN')),
#               (('through', 'IN'), ('federal', 'JJ'), ('facilities', 'NNS')),
#               (('poor', 'JJ'), ('hospital', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('margin', 'NN'), ('facility', 'NN')),
#               (('the', 'DT'), ('pipeline', 'NN'), ('facility', 'NN')),
#               (('productive', 'JJ'),
#                ('facilities', 'NNS'),
#                ('inventory', 'NN')),
#               (('the', 'DT'), ('last', 'JJ'), ('facility', 'NN')),
#               (('the', 'DT'), ('needed', 'JJ'), ('facilities', 'NNS')),
#               (('atlantic', 'JJ'), ('city', 'NN'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('engineering', 'NN')),
#               (('develop', 'VB'), ('port', 'NN'), ('facilities', 'NNS')),
#               (('day', 'NN'), ('processing', 'VBG'), ('facility', 'NN')),
#               (('term', 'NN'), ('care', 'NN'), ('facilities', 'NNS')),
#               (('its', 'PRP$'), ('attendant', 'NN'), ('facilities', 'NNS')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('space', 'NN')),
#               (('weather', 'PRP$'), ('facility', 'NN'), ('of', 'IN')),
#               (('cape', 'NN'), ('spencer', 'NN'), ('facilities', 'NNS')),
#               (('electric', 'JJ'), ('generation', 'NN'), ('facility', 'NN')),
#               (('the', 'DT'), ('two', 'CD'), ('facilities', 'NNS')),
#               (('emergency', 'NN'), ('toilet', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('new', 'JJ'), ('facility', 'NN')),
#               (('special', 'JJ'), ('purpose', 'NN'), ('facility', 'NN')),
#               (('eligible', 'JJ'),
#                ('productive', 'JJ'),
#                ('facilities', 'NNS')),
#               (('build', 'VB'), ('production', 'NN'), ('facilities', 'NNS')),
#               (('health', 'NN'), ('care', 'NN'), ('facilities', 'NNS')),
#               (('ecuador', 'NN'), ('oil', 'NN'), ('facility', 'NN')),
#               (('secured', 'JJ'), ('margin', 'NN'), ('facility', 'NN')),
#               (('new', 'JJ'), ('facility', 'NN'), ('replaces', 'NNS')),
#               (('building', 'NN'), ('research', 'NN'), ('facilities', 'NNS')),
#               (('buys', 'JJ'), ('aviation', 'NN'), ('facility', 'NN')),
#               (('nine', 'CD'), ('storage', 'NN'), ('facilities', 'NNS')),
#               (('a', 'DT'), ('regional', 'JJ'), ('facility', 'NN')),
#               (('certain', 'JJ'), ('port', 'NN'), ('facilities', 'NNS')),
#               (('facility', 'NN'), ('dynalectron', 'NNP'), ('corp', 'NN')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('techniques', 'NNS')),
#               (('export', 'NN'), ('credit', 'NN'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('facilities', 'NNS'), ('formerly', 'RB')),
#               (('the', 'DT'), ('production', 'NN'), ('facilities', 'NNS')),
#               (('11', 'CD'), ('bottling', 'NN'), ('facilities', 'NNS')),
#               (('sewage', 'NN'), ('treatment', 'NN'), ('facilities', 'NNS')),
#               (('bridge', 'NN'), ('financing', 'NN'), ('facility', 'NN')),
#               (('international', 'JJ'), ('debt', 'NN'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('&', 'CC'), ('lt', 'NN')),
#               (('having', 'VBG'), ('complete', 'JJ'), ('facilities', 'NNS')),
#               (('tender', 'NN'), ('offer', 'NN'), ('facility', 'NN')),
#               (('pct', 'JJ'), ('facility', 'NN'), ('rate', 'NN')),
#               (('central', 'JJ'), ('garage', 'NN'), ('facilities', 'NNS')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('meetings', 'NNS')),
#               (('the', 'DT'), ('credit', 'NN'), ('facility', 'NN')),
#               (('rationalisation', 'NN'), ('and', 'CC'), ('facility', 'NN')),
#               (('other', 'JJ'), ('champion', 'NN'), ('facilities', 'NNS')),
#               (('many', 'JJ'), ('credit', 'NN'), ('facilities', 'NNS')),
#               (('46', 'CD'), ('other', 'JJ'), ('facilities', 'NNS')),
#               (('85', 'CD'), ('pct', 'JJ'), ('facility', 'NN')),
#               (('the', 'DT'), ('loan', 'NN'), ('facility', 'NN')),
#               (('poor', 'JJ'), ('training', 'NN'), ('facilities', 'NNS')),
#               (('textile', 'NN'), ('fiber', 'NN'), ('facilities', 'NNS')),
#               (('low-cost', 'NN'), ('radiation', 'NN'), ('facilities', 'NNS')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('aids', 'NNS')),
#               (('site', 'NN'), ('treatment', 'NN'), ('facilities', 'NNS')),
#               (('on', 'IN'), ('credit', 'NN'), ('facility', 'NN')),
#               (('new', 'JJ'), ('coal', 'NN'), ('facility', 'NN')),
#               (('plants', 'NNS'), ('and', 'CC'), ('facilities', 'NNS')),
#               (('agricultural', 'JJ'), ('weather', 'NN'), ('facility', 'NN')),
#               (('move', 'VB'), ('production', 'NN'), ('facilities', 'NNS')),
#               (('structures', 'NNS'), ('and', 'CC'), ('facilities', 'NNS')),
#               (('the', 'DT'), ('adjoining', 'VBG'), ('facility', 'NN')),
#               (('nursing', 'NN'), ('care', 'NN'), ('facilities', 'NNS')),
#               (('a', 'DT'), ('different', 'JJ'), ('facility', 'NN')),
#               (('special', 'JJ'), ('borrowing', 'NN'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('businesses', 'NNS')),
#               (('a', 'DT'), ('productive', 'JJ'), ('facilities', 'NNS')),
#               (('sheep', 'NN'), ('slaughtering', 'NN'), ('facility', 'NN')),
#               (('facilities', 'NNS'), ('and', 'CC'), ('staff', 'NN')),
#               (('complete', 'JJ'),
#                ('facilities', 'NNS'),
#                ('inventories', 'NNS')),
#               (('talents', 'NNS'), ('and', 'CC'), ('facilities', 'NNS')),
#               (('debt', 'NN'), ('facility', 'NN'), ('."', 'NN')),
#               (('of', 'IN'), ('certain', 'JJ'), ('facilities', 'NNS')),
#               (('countries', 'NNS'), ('plus', 'CC'), ('facilities', 'NNS')),
#               (('tire', 'NN'), ('production', 'NN'), ('facility', 'NN')),
#               (('facility', 'NN'), ('and', 'CC'), ('related', 'JJ')),
#               (('financing', 'NN'), ('facility', 'NN'), ('due', 'JJ'))],
#              4: [(('loans', 'NNS'),
#                ('and', 'CC'),
#                ('bank', 'NN'),
#                ('facilities', 'NNS')),
#               (('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('test', 'NN'),
#                ('sites', 'NNS')),
#               (('mln', 'NN'),
#                ('dlr', 'NN'),
#                ('credit', 'NN'),
#                ('facility', 'NN')),
#               (('a', 'DT'), ('new', 'JJ'), ('coal', 'NN'), ('facility', 'NN')),
#               (('rationalisation', 'NN'),
#                ('and', 'CC'),
#                ('facility', 'NN'),
#                ('improvements', 'NNS')),
#               (('temporary', 'JJ'),
#                ('sewage', 'NN'),
#                ('treatment', 'NN'),
#                ('facilities', 'NNS')),
#               (('a', 'DT'),
#                ('sixth', 'JJ'),
#                ('production', 'NN'),
#                ('facility', 'NN')),
#               (('a', 'DT'),
#                ('structural', 'JJ'),
#                ('adjustment', 'NN'),
#                ('facility', 'NN')),
#               (('a', 'DT'),
#                ('secured', 'JJ'),
#                ('margin', 'NN'),
#                ('facility', 'NN')),
#               (('necessary', 'JJ'),
#                ('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('test', 'NN')),
#               (('production', 'NN'),
#                ('and', 'CC'),
#                ('distribution', 'NN'),
#                ('facilities', 'NNS')),
#               (('lone', 'NN'),
#                ('rock', 'NN'),
#                ('coop', 'NN'),
#                ('facility', 'NN')),
#               (('its', 'PRP$'),
#                ('paper', 'NN'),
#                ('mill', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('cape', 'NN'),
#                ('spencer', 'NN'),
#                ('facilities', 'NNS')),
#               (('certain', 'JJ'),
#                ('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('meetings', 'NNS')),
#               (('available', 'JJ'),
#                ('talents', 'NNS'),
#                ('and', 'CC'),
#                ('facilities', 'NNS')),
#               (('facility', 'NN'),
#                ('transfer', 'NN'),
#                ('or', 'CC'),
#                ('pumpover', 'NN')),
#               (('all', 'DT'),
#                ('eligible', 'JJ'),
#                ('productive', 'JJ'),
#                ('facilities', 'NNS')),
#               (('redundant', 'JJ'),
#                ('equipment', 'NN'),
#                ('and', 'CC'),
#                ('facilities', 'NNS')),
#               (('its', 'PRP$'),
#                ('acrylic', 'JJ'),
#                ('acid', 'JJ'),
#                ('facility', 'NN')),
#               (('a', 'DT'),
#                ('special', 'JJ'),
#                ('purpose', 'NN'),
#                ('facility', 'NN')),
#               (('offices', 'NNS'),
#                ('and', 'CC'),
#                ('factory', 'NN'),
#                ('facilities', 'NNS')),
#               (('ecuador', 'NN'),
#                ('oil', 'NN'),
#                ('facility', 'NN'),
#                ('banque', 'NN')),
#               (('with', 'IN'),
#                ('no', 'DT'),
#                ('small', 'JJ'),
#                ('facility', 'NN')),
#               (('church', 'NN'),
#                ('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('refreshments', 'NNS')),
#               (('the', 'DT'),
#                ('south', 'JJ'),
#                ('carolina', 'NN'),
#                ('facilities', 'NNS')),
#               (('cash', 'NN'),
#                ('and', 'CC'),
#                ('credit', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('space', 'NN')),
#               (('megawatt', 'NN'),
#                ('electric', 'JJ'),
#                ('generation', 'NN'),
#                ('facility', 'NN')),
#               (('educational', 'JJ'),
#                ('program', 'NN'),
#                ('and', 'CC'),
#                ('facilities', 'NNS')),
#               (('printing', 'NN'),
#                ('and', 'CC'),
#                ('lettershop', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('theatrical', 'JJ'),
#                ('facilities', 'NNS'),
#                ('available', 'JJ')),
#               (('r', 'NN'), ('&', 'CC'), ('d', 'NN'), ('facilities', 'NNS')),
#               (('adequate', 'JJ'),
#                ('central', 'JJ'),
#                ('garage', 'NN'),
#                ('facilities', 'NNS')),
#               (('a', 'DT'),
#                ('largely', 'RB'),
#                ('upgraded', 'JJ'),
#                ('facility', 'NN')),
#               (('its', 'PRP$'),
#                ('special', 'JJ'),
#                ('borrowing', 'NN'),
#                ('facility', 'NN')),
#               (('credit', 'NN'),
#                ('facility', 'NN'),
#                ('&', 'CC'),
#                ('lt', 'NN')),
#               (('medical', 'JJ'),
#                ('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('staff', 'NN')),
#               (('the', 'DT'),
#                ('needed', 'JJ'),
#                ('facilities', 'NNS'),
#                ('for', 'IN')),
#               (('the', 'DT'),
#                ('educational', 'JJ'),
#                ('facilities', 'NNS'),
#                ('of', 'IN')),
#               (('primary', 'JJ'),
#                ('medical', 'JJ'),
#                ('care', 'NN'),
#                ('facilities', 'NNS')),
#               (('lombard', 'JJ'),
#                ('emergency', 'NN'),
#                ('financing', 'NN'),
#                ('facility', 'NN')),
#               (('polyester', 'NN'),
#                ('textile', 'NN'),
#                ('fiber', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('largest', 'JJS'),
#                ('credit', 'NN'),
#                ('facility', 'NN')),
#               (('a', 'DT'),
#                ('bridge', 'NN'),
#                ('financing', 'NN'),
#                ('facility', 'NN')),
#               (('100', 'CD'),
#                ('facility', 'NN'),
#                ('expansion', 'NN'),
#                ('program', 'NN')),
#               (('a', 'DT'),
#                ('central', 'JJ'),
#                ('production', 'NN'),
#                ('facility', 'NN')),
#               (('storage', 'NN'),
#                ('structures', 'NNS'),
#                ('and', 'CC'),
#                ('facilities', 'NNS')),
#               (('distribution', 'NN'),
#                ('and', 'CC'),
#                ('manufacturing', 'NN'),
#                ('facilities', 'NNS')),
#               (('a', 'DT'),
#                ('revolving', 'NN'),
#                ('credit', 'NN'),
#                ('facility', 'NN')),
#               (('a', 'DT'),
#                ('compensatory', 'NN'),
#                ('financing', 'NN'),
#                ('facility', 'NN')),
#               (('shooting', 'VBG'),
#                ('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('activities', 'NNS')),
#               (('year', 'NN'),
#                ('100', 'CD'),
#                ('facility', 'NN'),
#                ('expansion', 'NN')),
#               (('shipping', 'NN'),
#                ('and', 'CC'),
#                ('office', 'NN'),
#                ('facilities', 'NNS')),
#               (('international', 'JJ'),
#                ('debt', 'NN'),
#                ('facility', 'NN'),
#                ('."', 'NN')),
#               (('additional', 'JJ'),
#                ('sewage', 'NN'),
#                ('treatment', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('tender', 'NN'),
#                ('offer', 'NN'),
#                ('facility', 'NN')),
#               (('the', 'DT'),
#                ('new', 'JJ'),
#                ('facility', 'NN'),
#                ('replaces', 'NNS')),
#               (('oil', 'NN'),
#                ('facility', 'NN'),
#                ('banque', 'NN'),
#                ('paribas', 'NN')),
#               (('mln', 'NN'),
#                ('dlr', 'NN'),
#                ('margin', 'NN'),
#                ('facility', 'NN')),
#               (('modification', 'NN'),
#                ('and', 'CC'),
#                ('maintenance', 'NN'),
#                ('facility', 'NN')),
#               (('major', 'JJ'),
#                ('health', 'NN'),
#                ('care', 'NN'),
#                ('facilities', 'NNS')),
#               (('fluidized', 'JJ'),
#                ('bed', 'NN'),
#                ('combustion', 'NN'),
#                ('facility', 'NN')),
#               (('joint', 'JJ'),
#                ('agricultural', 'JJ'),
#                ('weather', 'NN'),
#                ('facility', 'NN')),
#               (('the', 'DT'),
#                ('compensatory', 'NN'),
#                ('financing', 'NN'),
#                ('facility', 'NN')),
#               (('85', 'CD'),
#                ('pct', 'JJ'),
#                ('facility', 'NN'),
#                ('rate', 'NN')),
#               (('the', 'DT'),
#                ('poor', 'JJ'),
#                ('training', 'NN'),
#                ('facilities', 'NNS')),
#               (('a', 'DT'),
#                ('productive', 'JJ'),
#                ('facilities', 'NNS'),
#                ('inventory', 'NN')),
#               (('community', 'NN'),
#                ('countries', 'NNS'),
#                ('plus', 'CC'),
#                ('facilities', 'NNS')),
#               (('a', 'DT'),
#                ('health', 'NN'),
#                ('club', 'NN'),
#                ('facility', 'NN')),
#               (('s', 'NN'),
#                ('tire', 'NN'),
#                ('production', 'NN'),
#                ('facility', 'NN')),
#               (('one', 'CD'),
#                ('sheep', 'NN'),
#                ('slaughtering', 'NN'),
#                ('facility', 'NN')),
#               (('the', 'DT'),
#                ('radio', 'NN'),
#                ('transmission', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('fluidized', 'JJ'),
#                ('bed', 'NN'),
#                ('facility', 'NN')),
#               (('additional', 'JJ'),
#                ('microchip', 'NN'),
#                ('production', 'NN'),
#                ('facilities', 'NNS')),
#               (('processing', 'NN'),
#                ('and', 'CC'),
#                ('distribution', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('productive', 'JJ'),
#                ('facilities', 'NNS'),
#                ('of', 'IN')),
#               (('our', 'PRP$'),
#                ('restricted', 'JJ'),
#                ('toilet', 'NN'),
#                ('facilities', 'NNS')),
#               (('facility', 'NN'),
#                ('and', 'CC'),
#                ('related', 'JJ'),
#                ('assets', 'NNS')),
#               (('term', 'NN'),
#                ('nursing', 'NN'),
#                ('care', 'NN'),
#                ('facilities', 'NNS')),
#               (('new', 'JJ'),
#                ('facilities', 'NNS'),
#                ('&', 'CC'),
#                ('lt', 'NN')),
#               (('the', 'DT'),
#                ('second', 'JJ'),
#                ('contingency', 'NN'),
#                ('facility', 'NN')),
#               (('new', 'JJ'),
#                ('atlantic', 'JJ'),
#                ('city', 'NN'),
#                ('facility', 'NN')),
#               (('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('engineering', 'NN'),
#                ('plans', 'NNS')),
#               (('ground', 'NN'),
#                ('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('aids', 'NNS')),
#               (('on', 'IN'),
#                ('the', 'DT'),
#                ('last', 'JJ'),
#                ('facility', 'NN')),
#               (('buys', 'JJ'),
#                ('aviation', 'NN'),
#                ('facility', 'NN'),
#                ('dynalectron', 'NNP')),
#               (('very', 'RB'),
#                ('poor', 'JJ'),
#                ('hospital', 'NN'),
#                ('facilities', 'NNS')),
#               (('gas', 'NN'),
#                ('and', 'CC'),
#                ('oil', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('physical', 'JJ'),
#                ('facilities', 'NNS'),
#                ('at', 'IN')),
#               (('its', 'PRP$'),
#                ('11', 'CD'),
#                ('bottling', 'NN'),
#                ('facilities', 'NNS'))],
#              5: [(('parochial', 'NN'),
#                ('and', 'CC'),
#                ('other', 'JJ'),
#                ('private-school', 'NN'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('fluidized', 'JJ'),
#                ('bed', 'NN'),
#                ('combustion', 'NN'),
#                ('facility', 'NN')),
#               (('the', 'DT'),
#                ('church', 'NN'),
#                ('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('refreshments', 'NNS')),
#               (('necessary', 'JJ'),
#                ('facilities', 'NNS'),
#                ('and', 'CC'),
#                ('test', 'NN'),
#                ('sites', 'NNS')),
#               (('the', 'DT'),
#                ('lone', 'NN'),
#                ('rock', 'NN'),
#                ('coop', 'NN'),
#                ('facility', 'NN')),
#               (('the', 'DT'),
#                ('new', 'JJ'),
#                ('atlantic', 'JJ'),
#                ('city', 'NN'),
#                ('facility', 'NN')),
#               (('syndicated', 'JJ'),
#                ('loans', 'NNS'),
#                ('and', 'CC'),
#                ('bank', 'NN'),
#                ('facilities', 'NNS')),
#               (('ecuador', 'NN'),
#                ('oil', 'NN'),
#                ('facility', 'NN'),
#                ('banque', 'NN'),
#                ('paribas', 'NN')),
#               (('its', 'PRP$'),
#                ('special', 'JJ'),
#                ('borrowing', 'NN'),
#                ('facility', 'NN'),
#                ('again', 'RB')),
#               (('the', 'DT'),
#                ('lombard', 'JJ'),
#                ('emergency', 'NN'),
#                ('financing', 'NN'),
#                ('facility', 'NN')),
#               (('european', 'JJ'),
#                ('community', 'NN'),
#                ('countries', 'NNS'),
#                ('plus', 'CC'),
#                ('facilities', 'NNS')),
#               (('the', 'DT'),
#                ('joint', 'JJ'),
#                ('agricultural', 'JJ'),
#                ('weather', 'NN'),
#                ('facility', 'NN'))]})

# %%
def extract_vocab(phrases_dict):
    voc = []
    
    for p_type, phrases in phrases_dict.items():
        for phr in phrases:
            voc.extend([token for token, tag in phr if token not in stop_words])
            
    return Counter(voc)

extract_vocab(not_sw)
# Out:
# Counter({'build': 1,
#          'campus': 2,
#          'dining': 2,
#          'dormitories': 3,
#          'dormitory': 4,
#          'gapt': 2})

# %% [markdown]
# # WordNet experiments

# %%
from nltk.corpus import wordnet as wn
